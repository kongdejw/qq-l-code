# %% [markdown]
# <a href="https://colab.research.google.com/github/kongdejw/qq-l-code/blob/main/CChapter_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
heart_df = pd.read_csv('/content/heart.csv', on_bad_lines='skip',engine="python")
heart_df.head()
# Out:
#    Year LocationAbbr    LocationDesc GeographicLevel DataSource  \
# 0  2019           AK  Aleutians East          County       NVSS
# 1  2019           AK  Aleutians West          County       NVSS
# 2  2019           AK       Anchorage          County       NVSS
# 3  2019           AK          Bethel          County       NVSS
# 4  2019           AK     Bristol Bay          County       NVSS
#
#                      Class                    Topic  Data_Value  \
# 0  Cardiovascular Diseases  Heart Disease Mortality       182.4
# 1  Cardiovascular Diseases  Heart Disease Mortality       172.6
# 2  Cardiovascular Diseases  Heart Disease Mortality       255.6
# 3  Cardiovascular Diseases  Heart Disease Mortality       343.4
# 4  Cardiovascular Diseases  Heart Disease Mortality         NaN
#
#           Data_Value_Unit                                    Data_Value_Type  \
# 0  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
# ...

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12378 entries, 0 to 12377
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Year                        12378 non-null  int64
#  1   LocationAbbr                12378 non-null  object
#  2   LocationDesc                12378 non-null  object
#  3   GeographicLevel             12378 non-null  object
#  4   DataSource                  12378 non-null  object
#  5   Class                       12377 non-null  object
#  6   Topic                       12377 non-null  object
#  7   Data_Value                  7630 non-null   float64
#  8   Data_Value_Unit             12377 non-null  object
#  9   Data_Value_Type             12377 non-null  object
#  10  Data_Value_Footnote_Symbol  4747 non-null   object
#  11  Data_Value_Footnote         4747 non-null   object
#  12  StratificationCategory1     12377 non-null  object
# ...

# %%
heart_df.isnull().sum()
# Out:
# Year                             0
# LocationAbbr                     0
# LocationDesc                     0
# GeographicLevel                  0
# DataSource                       0
# Class                            1
# Topic                            1
# Data_Value                    4748
# Data_Value_Unit                  1
# Data_Value_Type                  1
# Data_Value_Footnote_Symbol    7631
# Data_Value_Footnote           7631
# StratificationCategory1          1
# Stratification1                  1
# StratificationCategory2          1
# Stratification2                  1
# TopicID                          1
# LocationID                       1
# Y_lat                            1
# X_lon                            1
# dtype: int64

# %%
heart_df.Stratification2.unique()
# Out:
# array(['Overall', 'White', 'Black', 'Hispanic',
#        'Asian and Pacific Islander', 'American Indian and Alaskan Native',
#        None], dtype=object)

# %%
import seaborn as sns
sns.violinplot(x="Data_Value", y="Stratification2", data=heart_df)
# Out:
# <Axes: xlabel='Data_Value', ylabel='Stratification2'>

# %%
sns.displot(heart_df['Data_Value'])
